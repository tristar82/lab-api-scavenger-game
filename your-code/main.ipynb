# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
# import libraries here
import requests
import pandas as pd
import json
import numpy as np

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
# your code here
url = 'https://api.github.com'
url2 = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks'
forks = requests.get(url2)
type(forks)
# Out:
# requests.models.Response

# %%
r = requests.get(url2) 
# extracting data in json format 
data = r.json()

# %%
data[2]
# Out:
# {'id': 200138127,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyMDAxMzgxMjc=',
#  'name': 'mad-oct-2018',
#  'full_name': 'gggfaria/mad-oct-2018',
#  'private': False,
#  'owner': {'login': 'gggfaria',
#   'id': 13389357,
#   'node_id': 'MDQ6VXNlcjEzMzg5MzU3',
#   'avatar_url': 'https://avatars0.githubusercontent.com/u/13389357?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/gggfaria',
#   'html_url': 'https://github.com/gggfaria',
#   'followers_url': 'https://api.github.com/users/gggfaria/followers',
#   'following_url': 'https://api.github.com/users/gggfaria/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/gggfaria/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/gggfaria/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/gggfaria/subscriptions',
#   'organizations_url': 'https://api.github.com/users/gggfaria/orgs',
#   'repos_url': 'https://api.github.com/users/gggfaria/repos',
# ...

# %%
df = pd.DataFrame(data)

# %%
df['language'].unique()
# Out:
# array([None, 'Jupyter Notebook', 'HTML', 'Python'], dtype=object)

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
lang_list = []
for i in df['language'].unique():
    lang_list.append(i)
    
lang_list#.remove(None)
# Out:
# [None, 'Jupyter Notebook', 'HTML', 'Python']

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
# your code here
# your code here
url = 'https://api.github.com'
url2 = 'https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits'
since = '20191101'
until = '20191111'
commits = requests.get(url2, params = {'since': '2018-11-01T00:00:00Z', 'until': '2018-11-11T00:00:00Z'})

# %%
commits.json() #do this to get a list of commits inside the JSON - before you add to the dataframe!
# Out:
# [{'sha': '2b8665ef74f2fff99adffe85e31e7c4122fbaf4a',
#   'node_id': 'MDY6Q29tbWl0MTUzNzIwODA0OjJiODY2NWVmNzRmMmZmZjk5YWRmZmU4NWUzMWU3YzQxMjJmYmFmNGE=',
#   'commit': {'author': {'name': 'Gobinde43',
#     'email': 'belenlinacero@gmail.com',
#     'date': '2018-11-09T08:13:30Z'},
#    'committer': {'name': 'Gobinde43',
#     'email': 'belenlinacero@gmail.com',
#     'date': '2018-11-09T08:13:30Z'},
#    'message': 'matplotlib lab datasets',
#    'tree': {'sha': '925bc174e32f2431214975097c1a35108c2a2803',
#     'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/trees/925bc174e32f2431214975097c1a35108c2a2803'},
#    'url': 'https://api.github.com/repos/ironhack-datalabs/mad-oct-2018/git/commits/2b8665ef74f2fff99adffe85e31e7c4122fbaf4a',
#    'comment_count': 0,
#    'verification': {'verified': False,
#     'reason': 'unsigned',
#     'signature': None,
#     'payload': None}},
# ...

# %%
data2 = commits.json() 
#print(data2)
df2 = pd.DataFrame(data2)
df2
# Out:
#                                                author  \
# 0   {'login': 'Gobinde43', 'id': 22130700, 'node_i...
# 1   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 2   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 3   {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 4   {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 5   {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 6   {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 7   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 8   {'login': 'eye8', 'id': 1659798, 'node_id': 'M...
# 9   {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 10  {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 11  {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 12  {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 13  {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 14  {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# 15  {'login': 'KBDS', 'id': 22459030, 'node_id': '...
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
# your code here

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
secret.json()
# Out:
# '\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-/YEVWs7BzxfKyUd6zVxjEQcXRWsLbcEjv045Rq8DSoipySmQblhVKxlXLva2GtNd5DhwCxHwW1RM0N9I7S2Vew==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-481a47a96965f6706fb41bae0d14b09a.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-rqlwdaP+8oV7JwHySo0RpslRQAvrs57OQxH/1vmIliL2vqPijry+bYuY
# ...

# %%
#url3 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
search = 'https://api.github.com/search/code?q=scavengerhunt+repo:ironhack-datalabs/scavenger+in:path'
#changed & to + symbol above JUST FOR GITHUB JUST FOR SEARCH! switch = tp colons

username = 'tristar82'
token = 'c615d5e8e640f1935f8ac7d23fca5fceef5ad167'

scav = requests.get(search, auth=(username,token) )
#scav = requests.get(search, params = {'q':'.scavengerhunt', 'repo':r'scavenger', 'in':'path'})

# %%
scav.json()
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0006.scavengerhunt',
#    'path': '15024/.0006.scavengerhunt',
#    'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#    'url': 'https://api.github.com/repositories/162375181/contents/15024/.0006.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/1c9064284a24b3486015eafdb391b141c27ada2b',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024/.0006.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/44225188?v=4',
# ...

# %%
scav_data = pd.DataFrame(scav.json()['items']) #pass in teh JSON here and just the items!!!

# %%
scav_data.sort_values(by=['name'], inplace=True)

# %%
scav.text
# Out:
# '{"message":"Validation Failed","errors":[{"message":"Must include at least one user, organization, or repository","resource":"Search","field":"q","code":"invalid"}],"documentation_url":"https://developer.github.com/v3/search/"}'

# %%
type(secret)
r = requests.get(url2) 
# extracting data in json format 
datach3 = secret.json() 
print(secret)

# %%
username = 'tristar82'
token = 'c615d5e8e640f1935f8ac7d23fca5fceef5ad167'


url3 = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'
ihack_response3 = requests.get(url3, auth=(username,token))
ihack_response3_json  = ihack_response3.json()

# %%
GET /repos/:owner/:repo/contents/:path
  
    'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{folders}/'
            
GET /repos/:owner/:repo/forks
'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
#scav_data.sort_values(by=['name'], inplace=True)
username = 'tristar82'
token = 'c615d5e8e640f1935f8ac7d23fca5fceef5ad167'

stg_list = []

headers = {'Accept': 'application/vnd.github.v3.raw'}



for path in scav_data['path']:
    url = f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{path}'
    stg_list.append(requests.get(url , auth=(username,token), headers=headers).text )
    
    
    
#search = 'https://api.github.com/search/code?q=scavengerhunt+repo:ironhack-datalabs/scavenger+in:path'
#changed & to + symbol above JUST FOR GITHUB JUST FOR SEARCH! switch = tp colons



#scav = requests.get(search, auth=(username,token) )

# %%
print(stg_list)
# Out:
# ['In\n', 'data\n', 'science,\n', '80\n', 'percent\n', 'of\n', 'time\n', 'spent\n', 'is\n', 'preparing\n', 'data,\n', '20\n', 'percent\n', 'of\n', 'time\n', 'is\n', 'spent\n', 'complaining\n', 'about\n', 'the\n', 'need\n', 'to\n', 'prepare\n', 'data.\n']

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
print(" ".join(stg_list))

#method rstrip
# Out:
# In
#  data
#  science,
#  80
#  percent
#  of
#  time
#  spent
#  is
#  preparing
#  data,
#  20
#  percent
#  of
#  time
#  is
#  spent
#  complaining
#  about
#  the
#  need
#  to
#  prepare
#  data.

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
# your code here

# %% [markdown]
# #### 5. Print out the joke.

# %%
# your code here
